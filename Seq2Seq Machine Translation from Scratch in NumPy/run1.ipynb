# %% [markdown]
# # GRU-based Encoder–Decoder for Machine Translation (NumPy)

# %% [markdown]
# In this project, I created a machine translation model using an encoder–decoder architecture built entirely from scratch in NumPy, without using any deep learning frameworks. The model translates from English to Japanese using a GRU (Gated Recurrent Unit).
# - Dataset: English Japanese sentence pairs selected from the Tatoeba Project
# - Architecture: Encoder–Decoder with GRU
# - Objective: Generate Japanese translations using only NumPy operations

# %% [markdown]
# ## Architecture Overview
# - **Embedding**: English and Japanese character tokens are first mapped to integer indices. Each index is embedded into a dense vector using separate embedding matrices.
# - **Encoder**: A GRU processes the full embedded English input sequence, the final hidden state is returned and represents the context of the entire input sentence.
# - **Decoder**: The decoder is another GRU that predicts the Japanese output one character at a time. It takes the embedded previous character and the hidden state from the previous step. The initial hidden state is the encoder's final hidden state.
# - **Output**: Immediately after running the decoder GRU on a time step, apply an FC layer to the hidden state at that time step to get output logits. Store those logits and at the end apply softmax.

# %% [markdown]
# ![Encoder Decoder Architecture](figures/ED_arch.png)
#
# Image source: Zhang, Aston and Lipton, Zachary C. and Li, Mu and Smola, Alexander J. - https://github.com/d2l-ai/d2l-en

# %% [markdown]
# ## 1. Loading and Filtering Sentence Pairs
#
# Read English Japanese sentence pairs from the `jpn.txt` file. Because training a model from scratch using only NumPy means we can't use a gpu, we need to make the dataset smaller. We only use sentences with 3 or less words. lowercase the English text, and clean both languages using regular expressions.
#
# For English, we remove all non-alphanumeric characters. For Japanese, we preserve Hiragana, Katakana, Kanji, and a few key punctuation symbols (like 。 and 、). Duplicate English sentences are also removed to avoid redundancy.

# %%
import numpy as np
import re

# Lists for cleaned sentences
eng_sentences = []
jpn_sentences = []

# To avoid duplicates
seen = set()

with open("jpn.txt", "r", encoding="utf-8") as f:
    for line in f:
        parts = line.strip().split("\t")

        # Extract English and Japanese parts
        eng = parts[0].strip().lower()
        jpn = parts[1].strip().lower()

        # Clean English: keep lowercase letters, numbers, and spaces
        eng = re.sub(r"[^a-z0-9\s]", "", eng)

        # Clean Japanese: keep the punctuation
        jpn = re.sub(r"[^\u3040-\u30ff\u4e00-\u9fff。、！？\s]", "", jpn)
        # Filtering out sentences, max 3 words
        if len(eng.split()) <= 3 and len(jpn.split()) <= 3 and eng not in seen:
            eng_sentences.append(eng)
            jpn_sentences.append(jpn)
            seen.add(eng)

print(f"English Sentences: {eng_sentences[0:10]}")
print(f"English Sentences Length: {len(eng_sentences)}")
print(f"Japanese Sentences: {jpn_sentences[0:10]}")
print(f"Japanese Sentences Length: {len(jpn_sentences)}")
# Out:
# English Sentences: ['go', 'hi', 'run', 'who', 'wow', 'duck', 'fire', 'help', 'hide', 'jump']
# English Sentences Length: 6627
# Japanese Sentences: ['行け。', 'こんにちは。', '走れ。', '誰？', 'すごい！', '頭を下げろ！', '火事だ！', '助けて！', '隠れろ。', '飛び越えろ！']
# Japanese Sentences Length: 6627

# %% [markdown]
# ## Vocabulary Construction
#
# We now build vocabularies for both English and Japanese.
#
# - English is tokenized at word level. We assign indices to all words that appear more than twice.
# - Japanese is tokenized at the character level, since words are not separated by spaces. Characters appearing more than twice are included in the vocabulary.
#
# We also add special tokens:
#
# | Token | Meaning         |
# |-------|------------------|
# | `<pad>` | Padding token     |
# | `<unk>` | Unknown token     |
# | `<bos>` | Beginning of sequence |
# | `<eos>` | End of sequence     |

# %%
from collections import Counter

counter = Counter()

# Count word frequency
for sent in eng_sentences:
    counter.update(sent.split())

# English to index mapping
eng_to_ind = {'<pad>': 0, '<unk>':1}
ind = 2

# Include words that appear 3+ times.
for word in counter:
    if counter[word] > 2:
        eng_to_ind[word] = ind
        ind += 1
        
print("English Vocabulary Size:", len(eng_to_ind))

jcounter = Counter()

# Count character frequency across Japanese sentences
for sent in jpn_sentences:
    jcounter.update(list(sent))

# Japanese to index and index to Japanese mapping
jpn_to_ind = {'<pad>': 0, '<unk>': 1, '<bos>': 2, '<eos>': 3}
ind_to_jpn = {0: '<pad>', 1: '<unk>', 2: '<bos>', 3: '<eos>'}
ind = 4

# Include characters that appear 3+ times
for char, freq in jcounter.most_common():
    if freq > 2:
        jpn_to_ind[char] = ind
        ind_to_jpn[ind] = char
        ind += 1

print("Japanese Vocabulary Size:", len(jpn_to_ind))
# Out:
# English Vocabulary Size: 971
# Japanese Vocabulary Size: 847

# %% [markdown]
# ## Encoding Sentences
#
# Now convert each sentence into a sequence of integer indices.
#
# - English Encoding:
#   - Tokenized at the word level.
#   - Each sentence is padded to 3 tokens using the `<pad>` (index 0).
#   - Unknown words are mapped to `<unk>` (index 1).
#
# - Japanese Encoding:
#   - Tokenized at the character level.
#   - Each sentence starts with `<bos>` (index 2) and ends with `<eos>` (index 3).
#   - Limit to 12 tokens total to include both `<bos>` and `<eos>`.
#   - Padding (`<pad>`) is added at the end if needed.

# %%
eng_encoded = []

# Encode each English sentence at word level
# Maximum of 3 words per sentence
for sentence in eng_sentences:
    s = []
    for word in sentence.split():
        if word in eng_to_ind:
            s.append(eng_to_ind[word])
        else:
            s.append(1)
    while(len(s) < 3):
        s.append(0) # Padding
    eng_encoded.append(s)

jpn_encoded = []

# Encode each Japanese sentence character level
# Maximum of twelve characters per sentence including <bos> and <eos>
for sentence in jpn_sentences:
    s = [2] # 2 is <bos>
    for ch in sentence:
        if len(s) > 10:
            break # We need room to fit <eos> token.
        if ch in jpn_to_ind:
            s.append(jpn_to_ind[ch])
        else:
            s.append(1)   # 1 is <unk>
    s.append(3)           # 3 is <eos>
    while(len(s) < 12):
        s.append(0)       # 0 is <pad>
    jpn_encoded.append(s)

print(f"English Sentences Encoded: {eng_encoded[0:10]}")
print(f"English Sentences Encoded Length: {len(eng_encoded)}")
print(f"Japanese Sentences Encoded: {jpn_encoded[0:5]}")
print(f"Japanese Sentences Encoded Length: {len(jpn_encoded)}")
# Out:
# English Sentences Encoded: [[2, 0, 0], [3, 0, 0], [4, 0, 0], [5, 0, 0], [6, 0, 0], [1, 0, 0], [7, 0, 0], [8, 0, 0], [9, 0, 0], [10, 0, 0]]
# English Sentences Encoded Length: 6627
# Japanese Sentences Encoded: [[2, 71, 47, 4, 3, 0, 0, 0, 0, 0, 0, 0], [2, 29, 23, 27, 42, 6, 4, 3, 0, 0, 0, 0], [2, 213, 28, 4, 3, 0, 0, 0, 0, 0, 0, 0], [2, 65, 26, 3, 0, 0, 0, 0, 0, 0, 0, 0], [2, 12, 79, 5, 53, 3, 0, 0, 0, 0, 0, 0]]
# Japanese Sentences Encoded Length: 6627

# %% [markdown]
# ## Creating Embedding Matrices
#
# - Vocabulary Size: Approximately 900 for each language.
# - Embedding Dimension: I estimated using int(min(600, 1.6 * vocab_size ** 0.56)) = 72
#   I wanted to use a power of 2, so I rounded down to 64.
#
# Each word or character will be embedded into a 64 dimensional dense vector.

# %%
embedding_size = 64
V_eng = len(eng_to_ind)  # English vocab size
V_jpn = len(jpn_to_ind)  # Japanese vocab size

eng_embedding = np.random.randn(V_eng, embedding_size) * 0.1
jpn_embedding = np.random.randn(V_jpn, embedding_size) * 0.1

print(f"English embedding shape: {eng_embedding.shape}")
print(f"Japanese embedding shape: {jpn_embedding.shape}")

# Example
eng_sentence = [5, 23, 8]
embedded_sentence = eng_embedding[eng_sentence]  # Shape (3, 64)
print(f"English input shape: {embedded_sentence.shape}")  # (seq_len, embedding_dim)
# Out:
# English embedding shape: (971, 64)
# Japanese embedding shape: (847, 64)
# English input shape: (3, 64)

# %% [markdown]
# ## Activation and Loss Functions
#
# - Sigmoid: Used in GRU gates.
# - Tanh: Used for the candidate hidden state.
# - Softmax: Converts decoder logits into probabilities.
# - Cross Entropy Loss: Measures prediction error between predicted softmax outputs and true labels.
#
# Documentation generated by ChatGPT

# %%
def sigmoid(x):
    """
    Element-wise Sigmoid activation function.
    Used in GRU for update/reset gates.
    
    Clips input to avoid overflow in exp.
    """
    x = np.clip(x, -50, 50)  # Prevent overflow
    return 1 / (1 + np.exp(-x))

def sigmoid_deriv(x):
    """
    Derivative of the Sigmoid function.
    Used during GRU backpropagation.
    """
    s = sigmoid(x)
    return s * (1 - s)

def tanh(x):
    """
    Element-wise hyperbolic tangent activation.
    Used in GRU for candidate hidden state.
    """
    return np.tanh(x)

def tanh_deriv(x):
    """
    Derivative of tanh function.
    Used in GRU backpropagation.
    """
    return 1.0 - np.tanh(x) ** 2

def softmax(Z: np.ndarray) -> np.ndarray:
    """
    Apply softmax over last dimension (class logits).
    
    Parameters:
    - Z: np.ndarray of shape (batch_size, num_classes)
      Raw logits for classification.
    
    Returns:
    - np.ndarray of same shape: softmax probabilities.
    """
    Z = Z - np.max(Z, axis=1, keepdims=True)
    exp_Z = np.exp(Z)
    return exp_Z / np.sum(exp_Z, axis=1, keepdims=True)

def CrossEntropy(yhat: np.ndarray, y: np.ndarray, eps: float = 1e-15) -> float:
    """
    Compute mean cross-entropy loss.

    Parameters:
    - yhat: np.ndarray of shape (batch_size, num_classes)
        Predicted probabilities (after softmax)
    - y: np.ndarray of shape (batch_size,)
        True class indices
    - eps: float
        Small constant to avoid log(0)

    Returns:
    - float: mean loss across the batch
    """
    yhat = np.clip(yhat, eps, 1 - eps)  # Prevent log(0)
    correct_probs = yhat[np.arange(len(y)), y]
    return -np.mean(np.log(correct_probs))

# %% [markdown]
# ## GRU Architecture and Implementation
#
# The Gated Recurrent Unit (GRU) is an RNN cell designed to assist with the vanishing/exploding gradient problem and capture long range dependencies more efficiently than a vanilla RNN. Below is a overview of the implementation.
#
# - Reset Gate (R): Determines how much of the past hidden state to forget.
# - Update Gate (Z): Determines how much of the new candidate state to use versus retaining the past hidden state.

# %% [markdown]
# ## GRU Architecture and Implementation
#
# The Gated Recurrent Unit (GRU) is an RNN cell designed to assist with the vanishing/exploding gradient problem and capture long range dependencies more efficiently than a vanilla RNN. Below is a overview of the implementation.
#
# - Reset Gate (R): Determines how much of the past hidden state to forget.
# - Update Gate (Z): Determines how much of the new candidate state to use versus retaining the past hidden state.
# Rₜ = σ(xₜ @ W_r.T + hₜ₋₁ @ U_r + b_r)
# ### Forward Pass (per time step \(t\))
# 1. Compute gates
#     - Rₜ = σ(xₜ @ W_r.T + hₜ₋₁ @ U_r + b_r)
#     - Zₜ = σ(xₜ @ W_z.T + hₜ₋₁ @ U_z + b_z)
# 2. Candidate state
#     - Cₜ = tanh(xₜ @ W_c.T + (Rₜ ⊙ hₜ₋₁) @ U_c + b_c)
# 3. Hidden state update
#     - xₜ = zₜ ⊙ hₜ₋₁ + (1 - Zₜ) ⊙ Cₜ
#
# Store (xₜ, hₜ₋₁, Rₜ, Zₜ, Cₜ, hₜ) at each step to use during backpropagation.
#
# ![GRU Architecture](figures/GRU_arch.png)
#
# ### Gradient Calculations
#
# Calculating the gradients is a tedious process, below are my calculations to get this model to work. There were a lot of problems.
#
# ![Backpropagation](figures/Backprop.png)
#
# ### Integration into Encoder–Decoder
# - Encoder GRU: Processes the input sequence and returns the final hidden state \(h_{enc}\).
# - Decoder GRU: Initialized with \(h_{enc}\), generates the target sequence by feeding its own previous output back as input.

# %%
class GRU:
    def __init__(self, input_size, hidden_size):
        self.input_size = input_size
        self.hidden_size = hidden_size

        # Xavier Normal std
        std = np.sqrt(2 / (input_size + hidden_size))

        # Reset gate (R)
        self.r_w = np.random.normal(0, std, size=(hidden_size, input_size))
        self.r_u = np.random.normal(0, std, size=(hidden_size, hidden_size))
        self.r_b = np.zeros(hidden_size)

        # Update gate (Z)
        self.z_w = np.random.normal(0, std, size=(hidden_size, input_size))
        self.z_u = np.random.normal(0, std, size=(hidden_size, hidden_size))
        self.z_b = np.zeros(hidden_size)

        # Candidate hidden state (C)
        self.c_w = np.random.normal(0, std, size=(hidden_size, input_size))
        self.c_u = np.random.normal(0, std, size=(hidden_size, hidden_size))
        self.c_b = np.zeros(hidden_size)
    
    def forward(self, X, H=None):
        batch_size, seq_len, embed_dim = X.shape # (N, T, D)
        if H is None:
            H = np.zeros(shape=(batch_size, self.hidden_size)) # (N, H)

        hidden_states = []
        store = [] # For backpropagation

        for i in range(seq_len):
            x_t = X[:, i, :]  # (N, D)
            R = sigmoid(x_t @ self.r_w.T + H @ self.r_u + self.r_b)  # (N, H)
            Z = sigmoid(x_t @ self.z_w.T + H @ self.z_u + self.z_b)  # (N, H)
            C = tanh(x_t @ self.c_w.T + (R * H) @ self.c_u + self.c_b)  # (N, H)

            H_new = Z * H + (1 - Z) * C  # (N, H)

            store.append((x_t, H, R, Z, C, H_new))
            H = H_new
            hidden_states.append(H[:, np.newaxis, :])
            

        return H, np.concatenate(hidden_states, axis=1), store

    def backward(self, dH_all, store, lr):

        batch, seq_len, _ = dH_all.shape

        # Initialize accumulators for parameter gradients to zeros
        dr_w = np.zeros_like(self.r_w)  # ∂L/∂R_w, shape (H, D)
        dr_u = np.zeros_like(self.r_u)  # ∂L/∂R_u, shape (H, H)
        dr_b = np.zeros_like(self.r_b)  # ∂L/∂R_b,  shape (H,)

        dz_w = np.zeros_like(self.z_w)  # ∂L/∂Z_w
        dz_u = np.zeros_like(self.z_u)  # ∂L/∂Z_u
        dz_b = np.zeros_like(self.z_b)  # ∂L/∂Z_b

        dc_w = np.zeros_like(self.c_w)  # ∂L/∂C_w
        dc_u = np.zeros_like(self.c_u)  # ∂L/∂C_u
        dc_b = np.zeros_like(self.c_b)  # ∂L/∂C_b

        # dh accumulates the gradient flowing from future time steps
        dH = np.zeros((batch, self.hidden_size)) # (N, H)
        
        # Will hold gradient w.r.t. the input embeddings at each time step
        dx = np.zeros((batch, seq_len, self.input_size))  # (N, T, D)

        # Loop backwards through time: t = seq_len-1 ... 0
        for t in reversed(range(seq_len)):
            # Unpack stored values from forward pass
            # x_t:   (N, D) input at time t
            # h_prev:(N, H) previous hidden state
            # r_t:   (N, H) reset gate
            # z_t:   (N, H) update gate
            # c_t:   (N, H) candidate hidden state
            # h_t:   (N, H) final hidden state at time t
            x_t, h_prev, r_t, z_t, c_t, h_t = store[t]

            # dh: (N, H) total gradient wrt current hidden state h_t
            # Includes gradient from output loss and from next time step dH
            dh = dH_all[:, t, :] + dH
            
            # Gradients through update gate z_t and candidate c_t
            # ∂L/∂z_t = dh ⊙ (h_prev - c_t)
            dz = dh * (h_prev - c_t) # (N, H)
            # ∂L/∂c_t = dh ⊙ (1 - z_t)
            dc = dh * (1 - z_t)      # (N, H)
            # ∂L/∂h_prev = dh ⊙ z_t, one part of ∂L/∂h_{t-1}
            dh_prev = dh * z_t       # (N, H)

            # Backprop through tanh: ∂L/∂c_t_preact = dc ⊙ (1 - c_t²)
            dc_preact = dc * (1 - c_t**2)   # (N, H)
            
            # Accumulate parameter gradients for candidate weights
            # ∂L/∂C_w = dc_preact.T @ x_t
            dc_w += dc_preact.T @ x_t              # (H, D)
            # ∂L/∂C_u = (r_t ⊙ h_prev).T @ dc_preact
            dc_u += (r_t * h_prev).T @ dc_preact   # (H, H)
            # ∂L/∂C_b = sum over batch of dc_preact
            dc_b += np.sum(dc_preact, axis=0)      # (H,)

            # Reset gate gradient from C preact's hidden side
            # ∂L/∂r_t = ∂L/(∂C preact) ⊙ ∂(C preact)/∂r_t
            # ∂L/∂r_t = (dc_preact @ C_u.T) ⊙ h_prev
            dr = (dc_preact @ self.c_u.T) * h_prev   # (N, H)
            # Backprop through sigmoid: ∂L/∂r_preact = dr ⊙ r_t ⊙ (1 - r_t)
            dr_preact = dr * (r_t * (1 - r_t))       # (N, H)
            # Accumulate Reset gate gradients
            dr_w += dr_preact.T @ x_t                # (H, D)
            dr_u += h_prev.T @ dr_preact             # (H, H)
            dr_b += np.sum(dr_preact, axis=0)        # (H,)

            # Backprop through update gate sigmoid
            dz_preact = dz * z_t * (1 - z_t)         # (N, H)

            # Accumulate update gate gradients
            dz_w += dz_preact.T @ x_t                # (H, D)
            dz_u += h_prev.T @ dz_preact             # (H, H)
            dz_b += np.sum(dz_preact, axis=0)        # (H,)

            # Add to total gradient wrt h_prev
            # dh_prev = sum of all partials wrt h_prev from C, R, Z
            dh_prev += (dc_preact @ self.c_u.T) * r_t        # (N, H)
            dh_prev += dr_preact @ self.r_u.T                # (N, H)
            dh_prev += dz_preact @ self.z_u.T                # (N, H)
            

            # Set dH for next iteration (t-1)
            dH = dh_prev  # (N, H)

            dx = np.zeros((batch, seq_len, self.input_size))

            # Gradient wrt. input x_t combines contributions from each gate
            # Paths: dr_preact, dz_preact, dc_preact
            dx[:, t, :] = (
                dr_preact @ self.r_w +  # via reset gate input weights
                dz_preact @ self.z_w +  # via update gate input weights
                dc_preact @ self.c_w    # via candidate input weights
            )  # shape (N, D)


        grads = [dc_w, dc_u, dc_b, dr_w, dr_u, dr_b, dz_w, dz_u, dz_b]

        for i in range(len(grads)):
            np.clip(grads[i], -1.0, 1.0, out=grads[i])  # Gradient Clipping

        self.c_w -= lr * dc_w
        self.c_u -= lr * dc_u
        self.c_b -= lr * dc_b

        self.r_w -= lr * dr_w
        self.r_u -= lr * dr_u
        self.r_b -= lr * dr_b

        self.z_w -= lr * dz_w
        self.z_u -= lr * dz_u
        self.z_b -= lr * dz_b

        return dH, dx

# %% [markdown]
# Saving parameters function

# %%
def save_parameters(path, Encoder_GRU, Decoder_GRU, eng_embedding, jpn_embedding, o_w, o_b):

    np.savez(
        path,
        eng_embedding=eng_embedding,
        jpn_embedding=jpn_embedding,
        o_w=o_w, o_b=o_b,
        enc_r_w=Encoder_GRU.r_w, enc_r_u=Encoder_GRU.r_u, enc_r_b=Encoder_GRU.r_b,
        enc_z_w=Encoder_GRU.z_w, enc_z_u=Encoder_GRU.z_u, enc_z_b=Encoder_GRU.z_b,
        enc_c_w=Encoder_GRU.c_w, enc_c_u=Encoder_GRU.c_u, enc_c_b=Encoder_GRU.c_b,
        dec_r_w=Decoder_GRU.r_w, dec_r_u=Decoder_GRU.r_u, dec_r_b=Decoder_GRU.r_b,
        dec_z_w=Decoder_GRU.z_w, dec_z_u=Decoder_GRU.z_u, dec_z_b=Decoder_GRU.z_b,
        dec_c_w=Decoder_GRU.c_w, dec_c_u=Decoder_GRU.c_u, dec_c_b=Decoder_GRU.c_b
    )
    print("Saved Parameters")

# %%
batch_size = 32
epochs = 1000
lr = 0.005
encoder_len = 3        # English length
target_len = 12        # Japanese length
hidden_size = 128

bos_id, pad_id, eos_id = 2, 0, 3

Encoder_GRU = GRU(64, hidden_size)
Decoder_GRU = GRU(64, hidden_size)

X = np.array(eng_encoded, dtype=int)
y = np.array(jpn_encoded, dtype=int)

V_jpn = jpn_embedding.shape[0]
o_w = np.random.randn(V_jpn, hidden_size) * 0.01
o_b = np.zeros(V_jpn)

past_loss = []
break_loop = False

for epoch in range(epochs):
    total_loss = 0

    perm = np.random.permutation(X.shape[0])
    X_train = X[perm]
    y_train = y[perm]

    for batch in range(0, X.shape[0], batch_size):
        end = min(batch + batch_size, X_train.shape[0])
        X_ids = X_train[batch:end]
        y_train_batch = y_train[batch:end]
        batch_len = X_ids.shape[0]
        
        # Encoder forward
        X_emb = eng_embedding[X_ids]
        h_enc, enc_h_all, enc_store = Encoder_GRU.forward(X_emb)

        decoder_input = np.concatenate(
            [np.full((batch_len, 1), bos_id, dtype=int), y_train_batch[:, :-1]],
            axis=1
        )
        decoder_target = y_train_batch

        dec_in_emb = jpn_embedding[decoder_input]        # (N, T, D)
        _, h_dec_all, dec_store = Decoder_GRU.forward(dec_in_emb, h_enc)

        logits_flat = (h_dec_all @ o_w.T + o_b).reshape(-1, V_jpn) # (bs*seq_len, V_jpn)
        targets_flat = decoder_target.reshape(-1)

        mask = (targets_flat != pad_id)
        probs = softmax(logits_flat)
        probs = np.clip(probs, 1e-12, 1 - 1e-12)
        
        loss = -np.sum(np.log(probs[np.where(mask)[0], targets_flat[mask]])) / mask.sum()
        total_loss += loss * batch_len

        # Backprop through softmax + cross entropy
        dlogits = probs
        dlogits[np.where(mask)[0], targets_flat[mask]] -= 1
        dlogits /= mask.sum()  # average over non pad tokens

        # Final linear layer grad
        h_dec_all_flat = h_dec_all.reshape(-1, hidden_size)
        do_w = dlogits.T @ h_dec_all_flat    # (V_jpn, H)
        do_b = np.sum(dlogits, axis=0)       # (V_jpn,)
        dh_dec = dlogits @ o_w
        dh_dec = dh_dec.reshape(batch_len, target_len, hidden_size)

        # Decoder GRU backward
        dH_enc_from_dec, dx_dec = Decoder_GRU.backward(dh_dec, dec_store, lr)

        # Update decoder embeddings
        for b in range(batch_len):
            for t in range(target_len):
                idx_tok = decoder_input[b, t]
                jpn_embedding[idx_tok] -= lr * dx_dec[b, t]

        # Encoder GRU backward
        # Build gradient tensor with only last time-step having gradient
        dH_enc_all = np.zeros_like(enc_h_all)           # (B, encoder_len, H)
        dH_enc_all[:, -1, :] = dH_enc_from_dec          # gradient only on final encoder state
        _, dx_enc = Encoder_GRU.backward(dH_enc_all, enc_store, lr)

        # Update encoder embeddings
        for b in range(batch_len):
            for t in range(encoder_len):
                tok = X_ids[b, t]
                eng_embedding[tok] -= lr * dx_enc[b, t]

        # Update output layer
        o_w -= lr * do_w
        o_b -= lr * do_b

    tl = total_loss / X_train.shape[0]
    print(f"Epoch {epoch+1} | Loss: {tl:.4f}")

    past_loss.append(tl)
    if len(past_loss) > 5:
        if past_loss[-1] < tl and past_loss[-2] < tl:
            break_loop = True

    if break_loop:
        break

save_parameters("model_params.npz", Encoder_GRU, Decoder_GRU, eng_embedding, jpn_embedding, o_w, o_b)
# Out:
# Epoch 1 | Loss: 6.7245
# Epoch 2 | Loss: 6.6897
# Epoch 3 | Loss: 6.6543
# Epoch 4 | Loss: 6.6178
# Epoch 5 | Loss: 6.5792
# Epoch 6 | Loss: 6.5371
# Epoch 7 | Loss: 6.4887
# Epoch 8 | Loss: 6.4291
# Epoch 9 | Loss: 6.3481
# Epoch 10 | Loss: 6.2232
# Epoch 11 | Loss: 6.0019
# Epoch 12 | Loss: 5.6737
# Epoch 13 | Loss: 5.4196
# Epoch 14 | Loss: 5.2253
# Epoch 15 | Loss: 5.0598
# Epoch 16 | Loss: 4.9201
# Epoch 17 | Loss: 4.8054
# Epoch 18 | Loss: 4.7093
# Epoch 19 | Loss: 4.6317
# Epoch 20 | Loss: 4.5678
# Epoch 21 | Loss: 4.5153
# Epoch 22 | Loss: 4.4690
# Epoch 23 | Loss: 4.4283
# Epoch 24 | Loss: 4.3913
# Epoch 25 | Loss: 4.3568
# Epoch 26 | Loss: 4.3242
# Epoch 27 | Loss: 4.2944
# Epoch 28 | Loss: 4.2667
# Epoch 29 | Loss: 4.2411
# Epoch 30 | Loss: 4.2176
# Epoch 31 | Loss: 4.1958
# Epoch 32 | Loss: 4.1768
# Epoch 33 | Loss: 4.1595
# Epoch 34 | Loss: 4.1439
# Epoch 35 | Loss: 4.1305
# Epoch 36 | Loss: 4.1188
# Epoch 37 | Loss: 4.1076
# Epoch 38 | Loss: 4.0975
# Epoch 39 | Loss: 4.0882
# Epoch 40 | Loss: 4.0804
# Epoch 41 | Loss: 4.0736
# Epoch 42 | Loss: 4.0657
# Epoch 43 | Loss: 4.0595
# Epoch 44 | Loss: 4.0536
# Epoch 45 | Loss: 4.0481
# Epoch 46 | Loss: 4.0414
# Epoch 47 | Loss: 4.0364
# Epoch 48 | Loss: 4.0317
# Epoch 49 | Loss: 4.0260
# Epoch 50 | Loss: 4.0206
# Epoch 51 | Loss: 4.0154
# Epoch 52 | Loss: 4.0110
# Epoch 53 | Loss: 4.0055
# Epoch 54 | Loss: 4.0007
# Epoch 55 | Loss: 3.9952
# Epoch 56 | Loss: 3.9906
# Epoch 57 | Loss: 3.9855
# Epoch 58 | Loss: 3.9815
# Epoch 59 | Loss: 3.9758
# Epoch 60 | Loss: 3.9719
# Epoch 61 | Loss: 3.9672
# Epoch 62 | Loss: 3.9623
# Epoch 63 | Loss: 3.9570
# Epoch 64 | Loss: 3.9527
# Epoch 65 | Loss: 3.9475
# Epoch 66 | Loss: 3.9438
# Epoch 67 | Loss: 3.9390
# Epoch 68 | Loss: 3.9338
# Epoch 69 | Loss: 3.9293
# Epoch 70 | Loss: 3.9255
# Epoch 71 | Loss: 3.9207
# Epoch 72 | Loss: 3.9160
# Epoch 73 | Loss: 3.9124
# Epoch 74 | Loss: 3.9077
# Epoch 75 | Loss: 3.9034
# Epoch 76 | Loss: 3.8990
# Epoch 77 | Loss: 3.8950
# Epoch 78 | Loss: 3.8910
# Epoch 79 | Loss: 3.8868
# Epoch 80 | Loss: 3.8827
# Epoch 81 | Loss: 3.8784
# Epoch 82 | Loss: 3.8753
# Epoch 83 | Loss: 3.8706
# Epoch 84 | Loss: 3.8673
# Epoch 85 | Loss: 3.8628
# Epoch 86 | Loss: 3.8595
# Epoch 87 | Loss: 3.8557
# Epoch 88 | Loss: 3.8518
# Epoch 89 | Loss: 3.8488
# Epoch 90 | Loss: 3.8451
# Epoch 91 | Loss: 3.8419
# Epoch 92 | Loss: 3.8390
# Epoch 93 | Loss: 3.8352
# Epoch 94 | Loss: 3.8316
# Epoch 95 | Loss: 3.8290
# Epoch 96 | Loss: 3.8255
# Epoch 97 | Loss: 3.8225
# Epoch 98 | Loss: 3.8194
# Epoch 99 | Loss: 3.8163
# Epoch 100 | Loss: 3.8136
# Epoch 101 | Loss: 3.8111
# Epoch 102 | Loss: 3.8080
# Epoch 103 | Loss: 3.8050
# Epoch 104 | Loss: 3.8026
# Epoch 105 | Loss: 3.8001
# Epoch 106 | Loss: 3.7973
# Epoch 107 | Loss: 3.7949
# Epoch 108 | Loss: 3.7922
# Epoch 109 | Loss: 3.7896
# Epoch 110 | Loss: 3.7873
# Epoch 111 | Loss: 3.7853
# Epoch 112 | Loss: 3.7827
# Epoch 113 | Loss: 3.7802
# Epoch 114 | Loss: 3.7781
# Epoch 115 | Loss: 3.7757
# Epoch 116 | Loss: 3.7736
# Epoch 117 | Loss: 3.7715
# Epoch 118 | Loss: 3.7690
# Epoch 119 | Loss: 3.7671
# Epoch 120 | Loss: 3.7652
# Epoch 121 | Loss: 3.7631
# Epoch 122 | Loss: 3.7612
# Epoch 123 | Loss: 3.7593
# Epoch 124 | Loss: 3.7571
# Epoch 125 | Loss: 3.7555
# Epoch 126 | Loss: 3.7537
# Epoch 127 | Loss: 3.7517
# Epoch 128 | Loss: 3.7500
# Epoch 129 | Loss: 3.7482
# Epoch 130 | Loss: 3.7467
# Epoch 131 | Loss: 3.7448
# Epoch 132 | Loss: 3.7428
# Epoch 133 | Loss: 3.7413
# Epoch 134 | Loss: 3.7394
# Epoch 135 | Loss: 3.7377
# Epoch 136 | Loss: 3.7362
# Epoch 137 | Loss: 3.7343
# Epoch 138 | Loss: 3.7330
# Epoch 139 | Loss: 3.7313
# Epoch 140 | Loss: 3.7299
# Epoch 141 | Loss: 3.7279
# Epoch 142 | Loss: 3.7266
# Epoch 143 | Loss: 3.7249
# Epoch 144 | Loss: 3.7233
# Epoch 145 | Loss: 3.7220
# Epoch 146 | Loss: 3.7205
# Epoch 147 | Loss: 3.7190
# Epoch 148 | Loss: 3.7177
# Epoch 149 | Loss: 3.7159
# Epoch 150 | Loss: 3.7144
# Epoch 151 | Loss: 3.7126
# Epoch 152 | Loss: 3.7114
# Epoch 153 | Loss: 3.7098
# Epoch 154 | Loss: 3.7084
# Epoch 155 | Loss: 3.7066
# Epoch 156 | Loss: 3.7055
# Epoch 157 | Loss: 3.7044
# Epoch 158 | Loss: 3.7027
# Epoch 159 | Loss: 3.7008
# Epoch 160 | Loss: 3.7001
# Epoch 161 | Loss: 3.6988
# Epoch 162 | Loss: 3.6972
# Epoch 163 | Loss: 3.6955
# Epoch 164 | Loss: 3.6938
# Epoch 165 | Loss: 3.6926
# Epoch 166 | Loss: 3.6910
# Epoch 167 | Loss: 3.6902
# Epoch 168 | Loss: 3.6883
# Epoch 169 | Loss: 3.6873
# Epoch 170 | Loss: 3.6865
# Epoch 171 | Loss: 3.6844
# Epoch 172 | Loss: 3.6828
# Epoch 173 | Loss: 3.6816
# Epoch 174 | Loss: 3.6801
# Epoch 175 | Loss: 3.6789
# Epoch 176 | Loss: 3.6770
# Epoch 177 | Loss: 3.6754
# Epoch 178 | Loss: 3.6738
# Epoch 179 | Loss: 3.6730
# Epoch 180 | Loss: 3.6714
# Epoch 181 | Loss: 3.6699
# Epoch 182 | Loss: 3.6687
# Epoch 183 | Loss: 3.6672
# Epoch 184 | Loss: 3.6655
# Epoch 185 | Loss: 3.6638
# Epoch 186 | Loss: 3.6626
# Epoch 187 | Loss: 3.6614
# Epoch 188 | Loss: 3.6597
# Epoch 189 | Loss: 3.6578
# Epoch 190 | Loss: 3.6572
# Epoch 191 | Loss: 3.6552
# Epoch 192 | Loss: 3.6538
# Epoch 193 | Loss: 3.6524
# Epoch 194 | Loss: 3.6507
# Epoch 195 | Loss: 3.6489
# Epoch 196 | Loss: 3.6475
# Epoch 197 | Loss: 3.6461
# Epoch 198 | Loss: 3.6448
# Epoch 199 | Loss: 3.6431
# Epoch 200 | Loss: 3.6411
# Epoch 201 | Loss: 3.6402
# Epoch 202 | Loss: 3.6385
# Epoch 203 | Loss: 3.6365
# Epoch 204 | Loss: 3.6352
# Epoch 205 | Loss: 3.6335
# Epoch 206 | Loss: 3.6313
# Epoch 207 | Loss: 3.6300
# Epoch 208 | Loss: 3.6287
# Epoch 209 | Loss: 3.6268
# Epoch 210 | Loss: 3.6248
# Epoch 211 | Loss: 3.6232
# Epoch 212 | Loss: 3.6216
# Epoch 213 | Loss: 3.6202
# Epoch 214 | Loss: 3.6181
# Epoch 215 | Loss: 3.6165
# Epoch 216 | Loss: 3.6145
# Epoch 217 | Loss: 3.6131
# Epoch 218 | Loss: 3.6110
# Epoch 219 | Loss: 3.6099
# Epoch 220 | Loss: 3.6072
# Epoch 221 | Loss: 3.6059
# Epoch 222 | Loss: 3.6040
# Epoch 223 | Loss: 3.6025
# Epoch 224 | Loss: 3.6006
# Epoch 225 | Loss: 3.5985
# Epoch 226 | Loss: 3.5971
# Epoch 227 | Loss: 3.5953
# Epoch 228 | Loss: 3.5935
# Epoch 229 | Loss: 3.5917
# Epoch 230 | Loss: 3.5898
# Epoch 231 | Loss: 3.5884
# Epoch 232 | Loss: 3.5867
# Epoch 233 | Loss: 3.5848
# Epoch 234 | Loss: 3.5829
# Epoch 235 | Loss: 3.5811
# Epoch 236 | Loss: 3.5788
# Epoch 237 | Loss: 3.5771
# Epoch 238 | Loss: 3.5756
# Epoch 239 | Loss: 3.5742
# Epoch 240 | Loss: 3.5726
# Epoch 241 | Loss: 3.5706
# Epoch 242 | Loss: 3.5691
# Epoch 243 | Loss: 3.5670
# Epoch 244 | Loss: 3.5655
# Epoch 245 | Loss: 3.5637
# Epoch 246 | Loss: 3.5620
# Epoch 247 | Loss: 3.5605
# Epoch 248 | Loss: 3.5589
# Epoch 249 | Loss: 3.5574
# Epoch 250 | Loss: 3.5552
# Epoch 251 | Loss: 3.5536
# Epoch 252 | Loss: 3.5516
# Epoch 253 | Loss: 3.5501
# Epoch 254 | Loss: 3.5484
# Epoch 255 | Loss: 3.5469
# Epoch 256 | Loss: 3.5447
# Epoch 257 | Loss: 3.5435
# Epoch 258 | Loss: 3.5416
# Epoch 259 | Loss: 3.5401
# Epoch 260 | Loss: 3.5387
# Epoch 261 | Loss: 3.5367
# Epoch 262 | Loss: 3.5351
# Epoch 263 | Loss: 3.5339
# Epoch 264 | Loss: 3.5315
# Epoch 265 | Loss: 3.5301
# Epoch 266 | Loss: 3.5272
# Epoch 267 | Loss: 3.5261
# Epoch 268 | Loss: 3.5250
# Epoch 269 | Loss: 3.5227
# Epoch 270 | Loss: 3.5214
# Epoch 271 | Loss: 3.5196
# Epoch 272 | Loss: 3.5179
# Epoch 273 | Loss: 3.5159
# Epoch 274 | Loss: 3.5145
# Epoch 275 | Loss: 3.5127
# Epoch 276 | Loss: 3.5111
# Epoch 277 | Loss: 3.5094
# Epoch 278 | Loss: 3.5076
# Epoch 279 | Loss: 3.5051
# Epoch 280 | Loss: 3.5043
# Epoch 281 | Loss: 3.5022
# Epoch 282 | Loss: 3.5009
# Epoch 283 | Loss: 3.4991
# Epoch 284 | Loss: 3.4972
# Epoch 285 | Loss: 3.4958
# Epoch 286 | Loss: 3.4940
# Epoch 287 | Loss: 3.4923
# Epoch 288 | Loss: 3.4904
# Epoch 289 | Loss: 3.4883
# Epoch 290 | Loss: 3.4870
# Epoch 291 | Loss: 3.4857
# Epoch 292 | Loss: 3.4837
# Epoch 293 | Loss: 3.4817
# Epoch 294 | Loss: 3.4799
# Epoch 295 | Loss: 3.4787
# Epoch 296 | Loss: 3.4769
# Epoch 297 | Loss: 3.4754
# Epoch 298 | Loss: 3.4737
# Epoch 299 | Loss: 3.4717
# Epoch 300 | Loss: 3.4701
# Epoch 301 | Loss: 3.4684
# Epoch 302 | Loss: 3.4668
# Epoch 303 | Loss: 3.4649
# Epoch 304 | Loss: 3.4631
# Epoch 305 | Loss: 3.4611
# Epoch 306 | Loss: 3.4596
# Epoch 307 | Loss: 3.4578
# Epoch 308 | Loss: 3.4565
# Epoch 309 | Loss: 3.4545
# Epoch 310 | Loss: 3.4529
# Epoch 311 | Loss: 3.4516
# Epoch 312 | Loss: 3.4498
# Epoch 313 | Loss: 3.4476
# Epoch 314 | Loss: 3.4462
# Epoch 315 | Loss: 3.4440
# Epoch 316 | Loss: 3.4427
# Epoch 317 | Loss: 3.4412
# Epoch 318 | Loss: 3.4392
# Epoch 319 | Loss: 3.4378
# Epoch 320 | Loss: 3.4362
# Epoch 321 | Loss: 3.4344
# Epoch 322 | Loss: 3.4332
# Epoch 323 | Loss: 3.4313
# Epoch 324 | Loss: 3.4303
# Epoch 325 | Loss: 3.4283
# Epoch 326 | Loss: 3.4268
# Epoch 327 | Loss: 3.4255
# Epoch 328 | Loss: 3.4233
# Epoch 329 | Loss: 3.4223
# Epoch 330 | Loss: 3.4203
# Epoch 331 | Loss: 3.4193
# Epoch 332 | Loss: 3.4171
# Epoch 333 | Loss: 3.4169
# Epoch 334 | Loss: 3.4148
# Epoch 335 | Loss: 3.4132
# Epoch 336 | Loss: 3.4114
# Epoch 337 | Loss: 3.4103
# Epoch 338 | Loss: 3.4089
# Epoch 339 | Loss: 3.4071
# Epoch 340 | Loss: 3.4059
# Epoch 341 | Loss: 3.4045
# Epoch 342 | Loss: 3.4027
# Epoch 343 | Loss: 3.4020
# Epoch 344 | Loss: 3.4004
# Epoch 345 | Loss: 3.3992
# Epoch 346 | Loss: 3.3975
# Epoch 347 | Loss: 3.3965
# Epoch 348 | Loss: 3.3946
# Epoch 349 | Loss: 3.3935
# Epoch 350 | Loss: 3.3921
# Epoch 351 | Loss: 3.3908
# Epoch 352 | Loss: 3.3895
# Epoch 353 | Loss: 3.3883
# Epoch 354 | Loss: 3.3870
# Epoch 355 | Loss: 3.3859
# Epoch 356 | Loss: 3.3843
# Epoch 357 | Loss: 3.3836
# Epoch 358 | Loss: 3.3818
# Epoch 359 | Loss: 3.3810
# Epoch 360 | Loss: 3.3794
# Epoch 361 | Loss: 3.3790
# Epoch 362 | Loss: 3.3768
# Epoch 363 | Loss: 3.3760
# Epoch 364 | Loss: 3.3744
# Epoch 365 | Loss: 3.3736
# Epoch 366 | Loss: 3.3723
# Epoch 367 | Loss: 3.3708
# Epoch 368 | Loss: 3.3699
# Epoch 369 | Loss: 3.3687
# Epoch 370 | Loss: 3.3676
# Epoch 371 | Loss: 3.3664
# Epoch 372 | Loss: 3.3654
# Epoch 373 | Loss: 3.3642
# Epoch 374 | Loss: 3.3633
# Epoch 375 | Loss: 3.3618
# Epoch 376 | Loss: 3.3610
# Epoch 377 | Loss: 3.3599
# Epoch 378 | Loss: 3.3587
# Epoch 379 | Loss: 3.3577
# Epoch 380 | Loss: 3.3565
# Epoch 381 | Loss: 3.3558
# Epoch 382 | Loss: 3.3545
# Epoch 383 | Loss: 3.3533
# Epoch 384 | Loss: 3.3525
# Epoch 385 | Loss: 3.3514
# Epoch 386 | Loss: 3.3505
# Epoch 387 | Loss: 3.3492
# Epoch 388 | Loss: 3.3478
# Epoch 389 | Loss: 3.3468
# Epoch 390 | Loss: 3.3459
# Epoch 391 | Loss: 3.3447
# Epoch 392 | Loss: 3.3433
# Epoch 393 | Loss: 3.3431
# Epoch 394 | Loss: 3.3421
# Epoch 395 | Loss: 3.3412
# Epoch 396 | Loss: 3.3402
# Epoch 397 | Loss: 3.3389
# Epoch 398 | Loss: 3.3370
# Epoch 399 | Loss: 3.3372
# Epoch 400 | Loss: 3.3359
# Epoch 401 | Loss: 3.3350
# Epoch 402 | Loss: 3.3338
# Epoch 403 | Loss: 3.3331
# Epoch 404 | Loss: 3.3318
# Epoch 405 | Loss: 3.3309
# Epoch 406 | Loss: 3.3307
# Epoch 407 | Loss: 3.3287
# Epoch 408 | Loss: 3.3280
# Epoch 409 | Loss: 3.3273
# Epoch 410 | Loss: 3.3261
# Epoch 411 | Loss: 3.3251
# Epoch 412 | Loss: 3.3239
# Epoch 413 | Loss: 3.3234
# Epoch 414 | Loss: 3.3225
# Epoch 415 | Loss: 3.3220
# Epoch 416 | Loss: 3.3212
# Epoch 417 | Loss: 3.3191
# Epoch 418 | Loss: 3.3194
# Epoch 419 | Loss: 3.3175
# Epoch 420 | Loss: 3.3171
# Epoch 421 | Loss: 3.3160
# Epoch 422 | Loss: 3.3151
# Epoch 423 | Loss: 3.3139
# Epoch 424 | Loss: 3.3127
# Epoch 425 | Loss: 3.3125
# Epoch 426 | Loss: 3.3113
# Epoch 427 | Loss: 3.3110
# Epoch 428 | Loss: 3.3098
# Epoch 429 | Loss: 3.3089
# Epoch 430 | Loss: 3.3079
# Epoch 431 | Loss: 3.3067
# Epoch 432 | Loss: 3.3059
# Epoch 433 | Loss: 3.3055
# Epoch 434 | Loss: 3.3044
# Epoch 435 | Loss: 3.3038
# Epoch 436 | Loss: 3.3025
# Epoch 437 | Loss: 3.3023
# Epoch 438 | Loss: 3.3008
# Epoch 439 | Loss: 3.3008
# Epoch 440 | Loss: 3.2993
# Epoch 441 | Loss: 3.2985
# Epoch 442 | Loss: 3.2980
# Epoch 443 | Loss: 3.2965
# Epoch 444 | Loss: 3.2960
# Epoch 445 | Loss: 3.2951
# Epoch 446 | Loss: 3.2946
# Epoch 447 | Loss: 3.2929
# Epoch 448 | Loss: 3.2925
# Epoch 449 | Loss: 3.2920
# Epoch 450 | Loss: 3.2911
# Epoch 451 | Loss: 3.2901
# Epoch 452 | Loss: 3.2891
# Epoch 453 | Loss: 3.2883
# Epoch 454 | Loss: 3.2876
# Epoch 455 | Loss: 3.2862
# Epoch 456 | Loss: 3.2857
# Epoch 457 | Loss: 3.2848
# Epoch 458 | Loss: 3.2839
# Epoch 459 | Loss: 3.2839
# Epoch 460 | Loss: 3.2822
# Epoch 461 | Loss: 3.2819
# Epoch 462 | Loss: 3.2810
# Epoch 463 | Loss: 3.2801
# Epoch 464 | Loss: 3.2789
# Epoch 465 | Loss: 3.2785
# Epoch 466 | Loss: 3.2776
# Epoch 467 | Loss: 3.2768
# Epoch 468 | Loss: 3.2760
# Epoch 469 | Loss: 3.2759
# Epoch 470 | Loss: 3.2741
# Epoch 471 | Loss: 3.2736
# Epoch 472 | Loss: 3.2729
# Epoch 473 | Loss: 3.2722
# Epoch 474 | Loss: 3.2712
# Epoch 475 | Loss: 3.2702
# Epoch 476 | Loss: 3.2698
# Epoch 477 | Loss: 3.2685
# Epoch 478 | Loss: 3.2683
# Epoch 479 | Loss: 3.2676
# Epoch 480 | Loss: 3.2666
# Epoch 481 | Loss: 3.2653
# Epoch 482 | Loss: 3.2653
# Epoch 483 | Loss: 3.2642
# Epoch 484 | Loss: 3.2630
# Epoch 485 | Loss: 3.2623
# Epoch 486 | Loss: 3.2620
# Epoch 487 | Loss: 3.2611
# Epoch 488 | Loss: 3.2606
# Epoch 489 | Loss: 3.2597
# Epoch 490 | Loss: 3.2587
# Epoch 491 | Loss: 3.2580
# Epoch 492 | Loss: 3.2573
# Epoch 493 | Loss: 3.2569
# Epoch 494 | Loss: 3.2554
# Epoch 495 | Loss: 3.2553
# Epoch 496 | Loss: 3.2542
# Epoch 497 | Loss: 3.2533
# Epoch 498 | Loss: 3.2526
# Epoch 499 | Loss: 3.2526
# Epoch 500 | Loss: 3.2514
# Epoch 501 | Loss: 3.2504
# Epoch 502 | Loss: 3.2497
# Epoch 503 | Loss: 3.2487
# Epoch 504 | Loss: 3.2485
# Epoch 505 | Loss: 3.2472
# Epoch 506 | Loss: 3.2461
# Epoch 507 | Loss: 3.2460
# Epoch 508 | Loss: 3.2455
# Epoch 509 | Loss: 3.2448
# Epoch 510 | Loss: 3.2439
# Epoch 511 | Loss: 3.2430
# Epoch 512 | Loss: 3.2424
# Epoch 513 | Loss: 3.2412
# Epoch 514 | Loss: 3.2405
# Epoch 515 | Loss: 3.2402
# Epoch 516 | Loss: 3.2394
# Epoch 517 | Loss: 3.2382
# Epoch 518 | Loss: 3.2379
# Epoch 519 | Loss: 3.2366
# Epoch 520 | Loss: 3.2363
# Epoch 521 | Loss: 3.2356
# Epoch 522 | Loss: 3.2350
# Epoch 523 | Loss: 3.2344
# Epoch 524 | Loss: 3.2331
# Epoch 525 | Loss: 3.2323
# Epoch 526 | Loss: 3.2322
# Epoch 527 | Loss: 3.2313
# Epoch 528 | Loss: 3.2306
# Epoch 529 | Loss: 3.2304
# Epoch 530 | Loss: 3.2292
# Epoch 531 | Loss: 3.2285
# Epoch 532 | Loss: 3.2277
# Epoch 533 | Loss: 3.2270
# Epoch 534 | Loss: 3.2271
# Epoch 535 | Loss: 3.2255
# Epoch 536 | Loss: 3.2251
# Epoch 537 | Loss: 3.2241
# Epoch 538 | Loss: 3.2241
# Epoch 539 | Loss: 3.2229
# Epoch 540 | Loss: 3.2226
# Epoch 541 | Loss: 3.2215
# Epoch 542 | Loss: 3.2212
# Epoch 543 | Loss: 3.2197
# Epoch 544 | Loss: 3.2193
# Epoch 545 | Loss: 3.2189
# Epoch 546 | Loss: 3.2172
# Epoch 547 | Loss: 3.2168
# Epoch 548 | Loss: 3.2159
# Epoch 549 | Loss: 3.2157
# Epoch 550 | Loss: 3.2145
# Epoch 551 | Loss: 3.2144
# Epoch 552 | Loss: 3.2139
# Epoch 553 | Loss: 3.2128
# Epoch 554 | Loss: 3.2127
# Epoch 555 | Loss: 3.2112
# Epoch 556 | Loss: 3.2111
# Epoch 557 | Loss: 3.2106
# Epoch 558 | Loss: 3.2098
# Epoch 559 | Loss: 3.2089
# Epoch 560 | Loss: 3.2086
# Epoch 561 | Loss: 3.2078
# Epoch 562 | Loss: 3.2072
# Epoch 563 | Loss: 3.2065
# Epoch 564 | Loss: 3.2058
# Epoch 565 | Loss: 3.2046
# Epoch 566 | Loss: 3.2041
# Epoch 567 | Loss: 3.2036
# Epoch 568 | Loss: 3.2030
# Epoch 569 | Loss: 3.2025
# Epoch 570 | Loss: 3.2012
# Epoch 571 | Loss: 3.2013
# Epoch 572 | Loss: 3.2008
# Epoch 573 | Loss: 3.1995
# Epoch 574 | Loss: 3.1990
# Epoch 575 | Loss: 3.1988
# Epoch 576 | Loss: 3.1978
# Epoch 577 | Loss: 3.1973
# Epoch 578 | Loss: 3.1964
# Epoch 579 | Loss: 3.1958
# Epoch 580 | Loss: 3.1950
# Epoch 581 | Loss: 3.1949
# Epoch 582 | Loss: 3.1933
# Epoch 583 | Loss: 3.1933
# Epoch 584 | Loss: 3.1927
# Epoch 585 | Loss: 3.1924
# Epoch 586 | Loss: 3.1915
# Epoch 587 | Loss: 3.1906
# Epoch 588 | Loss: 3.1896
# Epoch 589 | Loss: 3.1895
# Epoch 590 | Loss: 3.1886
# Epoch 591 | Loss: 3.1881
# Epoch 592 | Loss: 3.1873
# Epoch 593 | Loss: 3.1869
# Epoch 594 | Loss: 3.1861
# Epoch 595 | Loss: 3.1855
# Epoch 596 | Loss: 3.1845
# Epoch 597 | Loss: 3.1843
# Epoch 598 | Loss: 3.1834
# Epoch 599 | Loss: 3.1827
# Epoch 600 | Loss: 3.1819
# Epoch 601 | Loss: 3.1815
# Epoch 602 | Loss: 3.1812
# Epoch 603 | Loss: 3.1803
# Epoch 604 | Loss: 3.1801
# Epoch 605 | Loss: 3.1790
# Epoch 606 | Loss: 3.1790
# Epoch 607 | Loss: 3.1787
# Epoch 608 | Loss: 3.1771
# Epoch 609 | Loss: 3.1770
# Epoch 610 | Loss: 3.1759
# Epoch 611 | Loss: 3.1758
# Epoch 612 | Loss: 3.1748
# Epoch 613 | Loss: 3.1741
# Epoch 614 | Loss: 3.1736
# Epoch 615 | Loss: 3.1731
# Epoch 616 | Loss: 3.1720
# Epoch 617 | Loss: 3.1715
# Epoch 618 | Loss: 3.1716
# Epoch 619 | Loss: 3.1705
# Epoch 620 | Loss: 3.1702
# Epoch 621 | Loss: 3.1692
# Epoch 622 | Loss: 3.1687
# Epoch 623 | Loss: 3.1681
# Epoch 624 | Loss: 3.1676
# Epoch 625 | Loss: 3.1670
# Epoch 626 | Loss: 3.1664
# Epoch 627 | Loss: 3.1655
# Epoch 628 | Loss: 3.1655
# Epoch 629 | Loss: 3.1650
# Epoch 630 | Loss: 3.1645
# Epoch 631 | Loss: 3.1633
# Epoch 632 | Loss: 3.1625
# Epoch 633 | Loss: 3.1622
# Epoch 634 | Loss: 3.1616
# Epoch 635 | Loss: 3.1613
# Epoch 636 | Loss: 3.1614
# Epoch 637 | Loss: 3.1603
# Epoch 638 | Loss: 3.1594
# Epoch 639 | Loss: 3.1580
# Epoch 640 | Loss: 3.1580
# Epoch 641 | Loss: 3.1578
# Epoch 642 | Loss: 3.1567
# Epoch 643 | Loss: 3.1565
# Epoch 644 | Loss: 3.1563
# Epoch 645 | Loss: 3.1554
# Epoch 646 | Loss: 3.1545
# Epoch 647 | Loss: 3.1541
# Epoch 648 | Loss: 3.1538
# Epoch 649 | Loss: 3.1525
# Epoch 650 | Loss: 3.1525
# Epoch 651 | Loss: 3.1521
# Epoch 652 | Loss: 3.1513
# Epoch 653 | Loss: 3.1497
# Epoch 654 | Loss: 3.1502
# Epoch 655 | Loss: 3.1500
# Epoch 656 | Loss: 3.1491
# Epoch 657 | Loss: 3.1483
# Epoch 658 | Loss: 3.1481
# Epoch 659 | Loss: 3.1475
# Epoch 660 | Loss: 3.1464
# Epoch 661 | Loss: 3.1459
# Epoch 662 | Loss: 3.1458
# Epoch 663 | Loss: 3.1455
# Epoch 664 | Loss: 3.1446
# Epoch 665 | Loss: 3.1441
# Epoch 666 | Loss: 3.1434
# Epoch 667 | Loss: 3.1430
# Epoch 668 | Loss: 3.1422
# Epoch 669 | Loss: 3.1419
# Epoch 670 | Loss: 3.1416
# Epoch 671 | Loss: 3.1407
# Epoch 672 | Loss: 3.1401
# Epoch 673 | Loss: 3.1399
# Epoch 674 | Loss: 3.1397
# Epoch 675 | Loss: 3.1383
# Epoch 676 | Loss: 3.1377
# Epoch 677 | Loss: 3.1376
# Epoch 678 | Loss: 3.1371
# Epoch 679 | Loss: 3.1368
# Epoch 680 | Loss: 3.1355
# Epoch 681 | Loss: 3.1353
# Epoch 682 | Loss: 3.1349
# Epoch 683 | Loss: 3.1335
# Epoch 684 | Loss: 3.1334
# Epoch 685 | Loss: 3.1333
# Epoch 686 | Loss: 3.1323
# Epoch 687 | Loss: 3.1321
# Epoch 688 | Loss: 3.1312
# Epoch 689 | Loss: 3.1312
# Epoch 690 | Loss: 3.1306
# Epoch 691 | Loss: 3.1299
# Epoch 692 | Loss: 3.1292
# Epoch 693 | Loss: 3.1284
# Epoch 694 | Loss: 3.1280
# Epoch 695 | Loss: 3.1278
# Epoch 696 | Loss: 3.1269
# Epoch 697 | Loss: 3.1277
# Epoch 698 | Loss: 3.1263
# Epoch 699 | Loss: 3.1254
# Epoch 700 | Loss: 3.1250
# Epoch 701 | Loss: 3.1242
# Epoch 702 | Loss: 3.1242
# Epoch 703 | Loss: 3.1229
# Epoch 704 | Loss: 3.1229
# Epoch 705 | Loss: 3.1227
# Epoch 706 | Loss: 3.1222
# Epoch 707 | Loss: 3.1215
# Epoch 708 | Loss: 3.1211
# Epoch 709 | Loss: 3.1205
# Epoch 710 | Loss: 3.1195
# Epoch 711 | Loss: 3.1193
# Epoch 712 | Loss: 3.1186
# Epoch 713 | Loss: 3.1179
# Epoch 714 | Loss: 3.1173
# Epoch 715 | Loss: 3.1172
# Epoch 716 | Loss: 3.1164
# Epoch 717 | Loss: 3.1164
# Epoch 718 | Loss: 3.1158
# Epoch 719 | Loss: 3.1145
# Epoch 720 | Loss: 3.1143
# Epoch 721 | Loss: 3.1140
# Epoch 722 | Loss: 3.1134
# Epoch 723 | Loss: 3.1127
# Epoch 724 | Loss: 3.1130
# Epoch 725 | Loss: 3.1119
# Epoch 726 | Loss: 3.1115
# Epoch 727 | Loss: 3.1106
# Epoch 728 | Loss: 3.1103
# Epoch 729 | Loss: 3.1098
# Epoch 730 | Loss: 3.1097
# Epoch 731 | Loss: 3.1084
# Epoch 732 | Loss: 3.1086
# Epoch 733 | Loss: 3.1074
# Epoch 734 | Loss: 3.1071
# Epoch 735 | Loss: 3.1067
# Epoch 736 | Loss: 3.1093
# Epoch 737 | Loss: 3.1059
# Epoch 738 | Loss: 3.1048
# Epoch 739 | Loss: 3.1040
# Epoch 740 | Loss: 3.1046
# Epoch 741 | Loss: 3.1039
# Epoch 742 | Loss: 3.1030
# Epoch 743 | Loss: 3.1025
# Epoch 744 | Loss: 3.1022
# Epoch 745 | Loss: 3.1019
# Epoch 746 | Loss: 3.1011
# Epoch 747 | Loss: 3.1006
# Epoch 748 | Loss: 3.1004
# Epoch 749 | Loss: 3.0998
# Epoch 750 | Loss: 3.0991
# Epoch 751 | Loss: 3.0987
# Epoch 752 | Loss: 3.1001
# Epoch 753 | Loss: 3.0974
# Epoch 754 | Loss: 3.0981
# Epoch 755 | Loss: 3.0968
# Epoch 756 | Loss: 3.0961
# Epoch 757 | Loss: 3.0956
# Epoch 758 | Loss: 3.0947
# Epoch 759 | Loss: 3.0950
# Epoch 760 | Loss: 3.0942
# Epoch 761 | Loss: 3.0939
# Epoch 762 | Loss: 3.0932
# Epoch 763 | Loss: 3.0929
# Epoch 764 | Loss: 3.0922
# Epoch 765 | Loss: 3.0922
# Epoch 766 | Loss: 3.0916
# Epoch 767 | Loss: 3.0911
# Epoch 768 | Loss: 3.0903
# Epoch 769 | Loss: 3.0899
# Epoch 770 | Loss: 3.0894
# Epoch 771 | Loss: 3.0888
# Epoch 772 | Loss: 3.0883
# Epoch 773 | Loss: 3.0881
# Epoch 774 | Loss: 3.0871
# Epoch 775 | Loss: 3.0865
# Epoch 776 | Loss: 3.0866
# Epoch 777 | Loss: 3.0863
# Epoch 778 | Loss: 3.0862
# Epoch 779 | Loss: 3.0856
# Epoch 780 | Loss: 3.0843
# Epoch 781 | Loss: 3.0841
# Epoch 782 | Loss: 3.0833
# Epoch 783 | Loss: 3.0833
# Epoch 784 | Loss: 3.0827
# Epoch 785 | Loss: 3.0823
# Epoch 786 | Loss: 3.0822
# Epoch 787 | Loss: 3.0814
# Epoch 788 | Loss: 3.0802
# Epoch 789 | Loss: 3.0802
# Epoch 790 | Loss: 3.0798
# Epoch 791 | Loss: 3.0796
# Epoch 792 | Loss: 3.0788
# Epoch 793 | Loss: 3.0781
# Epoch 794 | Loss: 3.0781
# Epoch 795 | Loss: 3.0775
# Epoch 796 | Loss: 3.0774
# Epoch 797 | Loss: 3.0761
# Epoch 798 | Loss: 3.0755
# Epoch 799 | Loss: 3.0753
# Epoch 800 | Loss: 3.0751
# Epoch 801 | Loss: 3.0745
# Epoch 802 | Loss: 3.0739
# Epoch 803 | Loss: 3.0735
# Epoch 804 | Loss: 3.0737
# Epoch 805 | Loss: 3.0723
# Epoch 806 | Loss: 3.0734
# Epoch 807 | Loss: 3.0718
# Epoch 808 | Loss: 3.0720
# Epoch 809 | Loss: 3.0711
# Epoch 810 | Loss: 3.0706
# Epoch 811 | Loss: 3.0702
# Epoch 812 | Loss: 3.0694
# Epoch 813 | Loss: 3.0689
# Epoch 814 | Loss: 3.0689
# Epoch 815 | Loss: 3.0681
# Epoch 816 | Loss: 3.0680
# Epoch 817 | Loss: 3.0670
# Epoch 818 | Loss: 3.0669
# Epoch 819 | Loss: 3.0661
# Epoch 820 | Loss: 3.0652
# Epoch 821 | Loss: 3.0663
# Epoch 822 | Loss: 3.0650
# Epoch 823 | Loss: 3.0643
# Epoch 824 | Loss: 3.0639
# Epoch 825 | Loss: 3.0635
# Epoch 826 | Loss: 3.0628
# Epoch 827 | Loss: 3.0625
# Epoch 828 | Loss: 3.0619
# Epoch 829 | Loss: 3.0620
# Epoch 830 | Loss: 3.0605
# Epoch 831 | Loss: 3.0606
# Epoch 832 | Loss: 3.0604
# Epoch 833 | Loss: 3.0592
# Epoch 834 | Loss: 3.0595
# Epoch 835 | Loss: 3.0588
# Epoch 836 | Loss: 3.0581
# Epoch 837 | Loss: 3.0579
# Epoch 838 | Loss: 3.0575
# Epoch 839 | Loss: 3.0568
# Epoch 840 | Loss: 3.0560
# Epoch 841 | Loss: 3.0562
# Epoch 842 | Loss: 3.0556
# Epoch 843 | Loss: 3.0554
# Epoch 844 | Loss: 3.0547
# Epoch 845 | Loss: 3.0537
# Epoch 846 | Loss: 3.0537
# Epoch 847 | Loss: 3.0533
# Epoch 848 | Loss: 3.0531
# Epoch 849 | Loss: 3.0523
# Epoch 850 | Loss: 3.0521
# Epoch 851 | Loss: 3.0525
# Epoch 852 | Loss: 3.0516
# Epoch 853 | Loss: 3.0514
# Epoch 854 | Loss: 3.0501
# Epoch 855 | Loss: 3.0490
# Epoch 856 | Loss: 3.0494
# Epoch 857 | Loss: 3.0488
# Epoch 858 | Loss: 3.0481
# Epoch 859 | Loss: 3.0480
# Epoch 860 | Loss: 3.0476
# Epoch 861 | Loss: 3.0472
# Epoch 862 | Loss: 3.0467
# Epoch 863 | Loss: 3.0464
# Epoch 864 | Loss: 3.0459
# Epoch 865 | Loss: 3.0453
# Epoch 866 | Loss: 3.0450
# Epoch 867 | Loss: 3.0442
# Epoch 868 | Loss: 3.0438
# Epoch 869 | Loss: 3.0437
# Epoch 870 | Loss: 3.0431
# Epoch 871 | Loss: 3.0425
# Epoch 872 | Loss: 3.0422
# Epoch 873 | Loss: 3.0420
# Epoch 874 | Loss: 3.0418
# Epoch 875 | Loss: 3.0416
# Epoch 876 | Loss: 3.0403
# Epoch 877 | Loss: 3.0401
# Epoch 878 | Loss: 3.0395
# Epoch 879 | Loss: 3.0394
# Epoch 880 | Loss: 3.0382
# Epoch 881 | Loss: 3.0381
# Epoch 882 | Loss: 3.0378
# Epoch 883 | Loss: 3.0379
# Epoch 884 | Loss: 3.0370
# Epoch 885 | Loss: 3.0364
# Epoch 886 | Loss: 3.0360
# Epoch 887 | Loss: 3.0356
# Epoch 888 | Loss: 3.0348
# Epoch 889 | Loss: 3.0350
# Epoch 890 | Loss: 3.0345
# Epoch 891 | Loss: 3.0334
# Epoch 892 | Loss: 3.0332
# Epoch 893 | Loss: 3.0323
# Epoch 894 | Loss: 3.0324
# Epoch 895 | Loss: 3.0322
# Epoch 896 | Loss: 3.0312
# Epoch 897 | Loss: 3.0308
# Epoch 898 | Loss: 3.0301
# Epoch 899 | Loss: 3.0304
# Epoch 900 | Loss: 3.0305
# Epoch 901 | Loss: 3.0297
# Epoch 902 | Loss: 3.0292
# Epoch 903 | Loss: 3.0288
# Epoch 904 | Loss: 3.0284
# Epoch 905 | Loss: 3.0275
# Epoch 906 | Loss: 3.0268
# Epoch 907 | Loss: 3.0265
# Epoch 908 | Loss: 3.0265
# Epoch 909 | Loss: 3.0261
# Epoch 910 | Loss: 3.0258
# Epoch 911 | Loss: 3.0252
# Epoch 912 | Loss: 3.0252
# Epoch 913 | Loss: 3.0241
# Epoch 914 | Loss: 3.0238
# Epoch 915 | Loss: 3.0233
# Epoch 916 | Loss: 3.0227
# Epoch 917 | Loss: 3.0227
# Epoch 918 | Loss: 3.0224
# Epoch 919 | Loss: 3.0215
# Epoch 920 | Loss: 3.0208
# Epoch 921 | Loss: 3.0205
# Epoch 922 | Loss: 3.0203
# Epoch 923 | Loss: 3.0199
# Epoch 924 | Loss: 3.0191
# Epoch 925 | Loss: 3.0189
# Epoch 926 | Loss: 3.0187
# Epoch 927 | Loss: 3.0183
# Epoch 928 | Loss: 3.0178
# Epoch 929 | Loss: 3.0169
# Epoch 930 | Loss: 3.0166
# Epoch 931 | Loss: 3.0164
# Epoch 932 | Loss: 3.0157
# Epoch 933 | Loss: 3.0156
# Epoch 934 | Loss: 3.0153
# Epoch 935 | Loss: 3.0147
# Epoch 936 | Loss: 3.0139
# Epoch 937 | Loss: 3.0140
# Epoch 938 | Loss: 3.0135
# Epoch 939 | Loss: 3.0127
# Epoch 940 | Loss: 3.0127
# Epoch 941 | Loss: 3.0122
# Epoch 942 | Loss: 3.0120
# Epoch 943 | Loss: 3.0116
# Epoch 944 | Loss: 3.0107
# Epoch 945 | Loss: 3.0104
# Epoch 946 | Loss: 3.0104
# Epoch 947 | Loss: 3.0104
# Epoch 948 | Loss: 3.0093
# Epoch 949 | Loss: 3.0086
# Epoch 950 | Loss: 3.0084
# Epoch 951 | Loss: 3.0076
# Epoch 952 | Loss: 3.0071
# Epoch 953 | Loss: 3.0069
# Epoch 954 | Loss: 3.0068
# Epoch 955 | Loss: 3.0068
# Epoch 956 | Loss: 3.0059
# Epoch 957 | Loss: 3.0052
# Epoch 958 | Loss: 3.0057
# Epoch 959 | Loss: 3.0041
# Epoch 960 | Loss: 3.0040
# Epoch 961 | Loss: 3.0036
# Epoch 962 | Loss: 3.0037
# Epoch 963 | Loss: 3.0024
# Epoch 964 | Loss: 3.0022
# Epoch 965 | Loss: 3.0021
# Epoch 966 | Loss: 3.0025
# Epoch 967 | Loss: 3.0011
# Epoch 968 | Loss: 3.0005
# Epoch 969 | Loss: 3.0003
# Epoch 970 | Loss: 2.9996
# Epoch 971 | Loss: 2.9998
# Epoch 972 | Loss: 2.9981
# Epoch 973 | Loss: 2.9984
# Epoch 974 | Loss: 2.9981
# Epoch 975 | Loss: 2.9977
# Epoch 976 | Loss: 2.9978
# Epoch 977 | Loss: 2.9966
# Epoch 978 | Loss: 2.9964
# Epoch 979 | Loss: 2.9956
# Epoch 980 | Loss: 2.9957
# Epoch 981 | Loss: 2.9952
# Epoch 982 | Loss: 2.9951
# Epoch 983 | Loss: 2.9941
# Epoch 984 | Loss: 2.9937
# Epoch 985 | Loss: 2.9936
# Epoch 986 | Loss: 2.9929
# Epoch 987 | Loss: 2.9924
# Epoch 988 | Loss: 2.9923
# Epoch 989 | Loss: 2.9921
# Epoch 990 | Loss: 2.9912
# Epoch 991 | Loss: 2.9910
# Epoch 992 | Loss: 2.9908
# Epoch 993 | Loss: 2.9902
# Epoch 994 | Loss: 2.9899
# Epoch 995 | Loss: 2.9897
# Epoch 996 | Loss: 2.9890
# Epoch 997 | Loss: 2.9891
# Epoch 998 | Loss: 2.9886
# Epoch 999 | Loss: 2.9877
# Epoch 1000 | Loss: 2.9873
# Saved Parameters

# %%
def predict(Encoder_GRU, Decoder_GRU, input_seq,
            eng_to_ind, eng_embedding,
            jpn_embedding, o_w, o_b,
            pad_id=0, unk_id=1, bos_id=2, eos_id=3,
            max_len=20, encoder_len=3):
    """
    Greedy decode.

    Returns list of predicted token ids excluding <eos>.
    """
    # Preprocess encoder input
    import re, numpy as np
    seq = re.sub(r"[^a-z0-9\s]", "", input_seq.strip().lower())
    src_tokens = [eng_to_ind.get(w, unk_id) for w in seq.split()]
    if not src_tokens:
        src_tokens = [pad_id]
    while len(src_tokens) < encoder_len:
        src_tokens.append(pad_id)
    src_tokens = src_tokens[:encoder_len]

    enc_embed = eng_embedding[src_tokens][None, ...]  # (1,T,D)
    h_enc, _, _ = Encoder_GRU.forward(enc_embed)      # (1,H)

    h = h_enc
    prev_token = bos_id
    preds = []

    for step in range(max_len):
        # Embed previous token
        y_embed = jpn_embedding[prev_token][None, :]   # (1,D)

        # One GRU step (manual to avoid allocation)
        r = sigmoid(y_embed @ Decoder_GRU.r_w.T + h @ Decoder_GRU.r_u + Decoder_GRU.r_b)
        z = sigmoid(y_embed @ Decoder_GRU.z_w.T + h @ Decoder_GRU.z_u + Decoder_GRU.z_b)
        c = tanh(y_embed @ Decoder_GRU.c_w.T + (r * h) @ Decoder_GRU.c_u + Decoder_GRU.c_b)
        h = z * h + (1 - z) * c # (1,H)

        logits = h @ o_w.T + o_b # (1,V_jpn)

        # Forbid <pad> and <bos> from being chosen
        logits[0, pad_id] = -1e9
        logits[0, bos_id] = -1e9

        next_token = int(np.argmax(logits, axis=1)[0])

        if next_token == eos_id:
            break

        preds.append(next_token)
        prev_token = next_token

    return preds

# %%
test = "Are you new?"
predicted_ids = predict(Encoder_GRU, Decoder_GRU, test, eng_to_ind, eng_embedding, jpn_embedding, o_w, o_b)
for i in predicted_ids:
    print(ind_to_jpn[i], end="")
# Out:
# トムってる。
